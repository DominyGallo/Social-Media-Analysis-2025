# %%
# load libraries
import spacy
from tqdm import tqdm
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MultiLabelBinarizer

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os

# %%
csv_path = "/content/drive/Shareddrives/NDC_txts/ndcs - sorted with indicators - All indicators (1) (1).csv"
txt_folder = "/content/drive/Shareddrives/NDC_txts"

# Load your CSV
df = pd.read_csv(csv_path)

# Function to read text from file
def read_text(filename):
    file_path = os.path.join(txt_folder, filename)
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            return f.read()
    except FileNotFoundError:
        return None  # or return "" if you prefer an empty string

# Apply the function to the 'filename' column
df["text_content"] = df["filename"].apply(read_text)

# %%
df["text_content"]
# Out:
# 0      1 \n \n \n \n \n \n \nISLAMIC REPUBLIC OF AFGH...
# 1       \n1\nALBANIA REVISED NDC \nALBANIA REVISED ND...
# 2      1 \n \n \n \n \n \n \nThe People’s Democratic ...
# 3      Third contribution\ndetermined at the\nAndorra...
# 4      Nationally Determined Contribution (NDC) of An...
#                              ...
# 189    Vanuatu’s Revised and Enhanced\n1st Nationally...
# 190    Nationally Determined Contribution\nNationally...
# 191    SOCIALIST REPUBLIC OF VIET NAM\nNATIONALLY DET...
# 192    REPUBLIC OF ZAMBIA\n1.0 Background\nThis docum...
# 193    ZIMBABWE’S NDC3.0 COUNTRY STATEMENT\n1ZIMBABWE...
# Name: text_content, Length: 194, dtype: object

# %%
# !pip install bertopic

# %%
# !pip install sentence_transformers
from sentence_transformers import SentenceTransformer
from bertopic import BERTopic
from umap import UMAP
from hdbscan import HDBSCAN
from sklearn.feature_extraction.text import CountVectorizer
import os

# %%
import os
from sentence_transformers import SentenceTransformer
from bertopic import BERTopic
from umap import UMAP
from hdbscan import HDBSCAN
from sklearn.feature_extraction.text import CountVectorizer

text_folder = "/content/drive/Shareddrives/NDC_txts"
documents = []  # Initialize an empty list to store your documents
for filename in os.listdir(text_folder):
    if filename.endswith(".txt"):
        with open(os.path.join(text_folder, filename), "r", encoding="utf-8") as f:
            documents.append(f.read())  # Append the content of each file to the list

# Now 'documents' contains all the text from the .txt files
# Proceed to generate the document_vectors using your model

# Ensure embeddings are generated from the 'documents' list
model = SentenceTransformer("all-MiniLM-L6-v2")
document_vectors = model.encode(documents, show_progress_bar=True)

# Define UMAP, HDBSCAN, and vectorizer before using them in BERTopic
umap_model = UMAP(n_neighbors=5, n_components=10, min_dist=0.0, metric='cosine', random_state=42)
umap_embeddings = umap_model.fit_transform(document_vectors)
hdbscan_model = HDBSCAN(min_cluster_size=2, metric='euclidean', cluster_selection_method='eom')
cluster_labels = hdbscan_model.fit_predict(umap_embeddings)
vectorizer = CountVectorizer(stop_words='english')

topic_model = BERTopic(
    embedding_model=model,
    umap_model=umap_model,
    hdbscan_model=hdbscan_model,
    vectorizer_model=vectorizer,
    verbose=True
).fit(documents, document_vectors)

# %%
# prompt: Can you help me ask it if is able to find any topic words?

# Get the topic info
topic_info = topic_model.get_topic_info()

# Print the topic info DataFrame to see if any topic words are present
topic_info
# Out:
#     Topic  Count                                        Name  \
# 0      -1     17            -1_high_climate_emissions_energy
# 1       0     29             0_eu_european_member_regulation
# 2       1     24              1_climate_sector_ndc_emissions
# 3       2     19        2_climate_change_national_adaptation
# 4       3      9                 3_oman_energy_water_climate
# 5       4      8               4_uae_climate_barbados_africa
# 6       5      8       5_moldova_republic_adaptation_climate
# 7       6      7            6_tonga_rwanda_climate_emissions
# 8       7      7          7_vanuatu_samoa_seychelles_climate
# 9       8      7   8_turkmenistan_türkiye_tajikistan_climate
# 10      9      7              9_canada_emissions_zero_target
# 11     10      7                             10_cid_24_13_15
# 12     11      5                11_bahamas_energy_bhutan_ndc
# 13     12      5        12_korea_georgia_republic_montenegro
# 14     13      5                   13_rmi_islands_st_solomon
# 15     14      4        14_dominica_antigua_barbuda_pakistan
# 16     15      4             15_climate_change_2020_national
# 17     16      4                    16_leste_timor_png_papua
# 18     17      4             17_chad_climate_change_national
# 19     18      4  18_suriname_cameroon_mauritania_madagascar
# 20     19      4          19_somalia_national_climate_change
# 21     20      3            20_cambodia_climate_chile_change
# 22     21      3    21_singapore_malaysia_thailand_emissions
#
#                                        Representation  \
# 0   [high, climate, emissions, energy, national, c...
# 1   [eu, european, member, regulation, states, uni...
# 2   [climate, sector, ndc, emissions, mitigation, ...
# 3   [climate, change, national, adaptation, countr...
# 4   [oman, energy, water, climate, national, egypt...
# 5   [uae, climate, barbados, africa, emissions, na...
# 6   [moldova, republic, adaptation, climate, devel...
# 7   [tonga, rwanda, climate, emissions, ndc, jorda...
# 8   [vanuatu, samoa, seychelles, climate, ndc, pal...
# 9   [turkmenistan, türkiye, tajikistan, climate, d...
# 10  [canada, emissions, zero, target, climate, net...
# 11          [cid, 24, 13, 15, 36, 16, 43, 22, 35, 10]
# 12  [bahamas, energy, bhutan, ndc, 2030, sri, clim...
# 13  [korea, georgia, republic, montenegro, ndc, ne...
# 14  [rmi, islands, st, solomon, kitts, nevis, clim...
# 15  [dominica, antigua, barbuda, pakistan, climate...
# 16  [climate, change, 2020, national, dominican, n...
# 17  [leste, timor, png, papua, guinea, development...
# 18  [chad, climate, change, national, nam, viet, a...
# 19  [suriname, cameroon, mauritania, madagascar, n...
# 20  [somalia, national, climate, change, ndc, adap...
# 21  [cambodia, climate, chile, change, women, ndc,...
# 22  [singapore, malaysia, thailand, emissions, ene...
#
#                                   Representative_Docs
# 0   [ \n \nLao People's Democratic Republic \nPeac...
# 1   [ \n \n \n \n1 \n \nUpdate of the \nNDC of the...
# 2   [MINISTRY OF WATER AND ENVIRONMENT\nUpdated Na...
# 3   [Nationally Determined Contribution\nNationall...
# 4   [0 \n \n1 \n \n \n \n2 \n \n \n  Executive Sum...
# 5   [Republic of Equatorial Guinea\n MINISTRY OF A...
# 6   [In accordance with decision No. 1/CP.21, para...
# 7   [ \n \n \n \n \n \n \n \nUPDATED SUBMISSION OF...
# 8   [The State of Palestine’s First Nationally\nDe...
# 9   [2 \nThe Republic of Uzbekistan, being committ...
# 10  [1 \n \nJapan’s Nationally Determined Contribu...
# 11  [NATIONALLY DETERMINED CONTRIBUTIONS\nCONTRIBU...
# 12  [ \n \n \n \nTable of Contents \nIntroduction ...
# 13  [Nationally Determined Contribution (NDC)\nof ...
# 14  [SOLOMON ISLANDS 2021\nNATIONALLY DETERMINED C...
# 15  [TABLE OF CONTENTS\n12 18\nCHAPTER 1 CHAPTER 2...
# 16  [Belize’s Updated Nationally Determined Contri...
# 17  [ \n \n \n \n \n \n \n \n \n \n \n \n \n \n \